# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 9))
'Optimizer Join Selection', 'Execution Time'
ax.barh(
    ['Enabled', 'Disabled'],
    [23.450059175491333, 32.473851919174194]
)
ax.set_title('Optimizer Join Selection')
ax.set_xlabel('time (s)')
plt.savefig('join_times.png')
