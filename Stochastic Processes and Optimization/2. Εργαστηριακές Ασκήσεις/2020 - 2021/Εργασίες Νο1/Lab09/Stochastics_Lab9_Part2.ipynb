# %% [markdown]
# ## [Νικόλαος Μανιάτης](mailto:nikolaosmaniatis@mail.ntua.gr)
# ## Α.Μ.: 03400097

# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/figures/PDSH-cover-small.png?raw=1">
#
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*
#
# <br>
# <strong>Για το εργαστήριο του μαθήματος "<i>Στοχαστικές Διεργασίες & Βελτιστοποίηση στη Μηχανική Μάθηση</i>" έχουμε προσαρμόσει το κείμενο και τον κώδικα από το παραπάνω βιβλίο στις ανάγκες μας.</strong>

# %% [markdown]
# <b>Τρέξτε το Notebook και απαντήστε, <u>συνοπτικά</u>, στις ερωτήσεις.</b>

# %% [markdown]
# <h2><b><i>Support Vector Machines</i></b></h2>

# %% [markdown]
# Αρχικά, θα φορτώσουμε τις βιβλιοθήκες που είναι απαραίτητες για την άσκηση. Όλες οι βιβλιοθήκες είναι εγκατεστημένες στο Colab.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.datasets import make_blobs
from sklearn.svm import SVC # "Support vector classifier"
from sklearn.datasets import make_circles
from ipywidgets import interact, fixed
from mpl_toolkits import mplot3d
import seaborn as sns; sns.set()

# %% [markdown]
# Το παρακάτω τμήμα κώδικα δημιουργεί και εμφανίζει δείγματα από 2 clusters με μία δεδομένη τυπική απόκλιση.

# %%
X, y = make_blobs(n_samples=50, centers=2,
                  random_state=0, cluster_std=0.60)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn');

# %% [markdown]
# Γίνεται εύκολα αντιληπτό ότι οι δύο κατηγορίες μπορούν να διαχωριστούν με ευθείες γραμμές. Στο παρακάτω σχήμα φαίνονται 3 τέτοιες ενδεικτικές γραμμές.
# <ul>
# <li><b>Ερώτηση 1:</b> Σε ποια κατηγορία θα ανήκει το test example που φαίνεται στην παρακάτω με εικόνα με το σύμβολο 'Χ' ανάλογα με την ευθεία γραμμή που θα επιλεχθεί; </li>
# <li><b>Ερώτηση 2:</b> Γιατί αυτή η μέθοδος διαχωρισμού των κλάσεων ενός ταξινομητή μπορεί να οδηγήσει σε μη επιθυμητά αποτελέσματα;</li>
# </ul>
#
#  <hr style="border:1px solid black"> </hr>
#
#  - Και οι 3 ευθείες γραμμές διαχωρίζουν τέλεια τις δυο κατηγορίες, επομένως το σύμβολο 'Χ' ανήκει σε διαφορετική κλάση ανάλογα με την γραμμή που θα επιλεχθεί. Στις δύο περιπτώσεις θα ανήκει στην κόκκινη κλάση ενώ στην άλλη περίπτωση θα ανήκει στην κίτρινη.
#
#  - Αυτή η μέθοδος διαχωρισμού μπορεί να οδηγήσει σε μη επιθυμητά αποτελέσματα καθώς μια non optimal (από τις άπειρες) ευθεία μπορεί να είναι πολύ κοντά στη μια κλάση και πολύ μακριά από την άλλη, επομένως αυτό αφαιρεί από τον αλγόριθμο ικανότητα γενίκευσης. Δηλαδή, αν κάποιο από τα test data είναι λίγο πιο μακριά από τα υπόλοιπα αυτό αυτομάτως θα γίνει missclassified. Γι'αυτό με τα SVMs προσπαθούμε να μεγιστοποιήσουμε το περιθώριο μεταξύ των κλάσεων.

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plt.plot([0.6], [2.1], 'x', color='red', markeredgewidth=2, markersize=10)

for m, b in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
    plt.plot(xfit, m * xfit + b, '-k')

plt.xlim(-1, 3.5);

# %% [markdown]
# Στην περίπτωση του ταξινομητή SVM το πρόβλημα αυτό επιλύεται με τον παρακάτω τρόπο: Αντί να τραβήξουμε μία γραμμή μηδενικού πλάτους ανάμεσα στις δύο κλάσεις, τραβάμε μία γραμμή με περιθώρια (margins) στις δύο πλευρές της. Η μέθοδος αυτή για τις γραμμές του προηγούμενου προβλήματος φαίνεται στην παρακάτω εικόνα.
# <ul>
# <li><b>Ερώτηση 3:</b> Ποιος περιορισμός ισχύει για τα περιθώρια της εκάστοτε γραμμής;</li>
# <li><b>Ερώτηση 4:</b> Με ποιο κριτήριο επιλέγεται η καλύτερη γραμμή;</li>
# </ul>
#  <hr style="border:1px solid black"> </hr>
#
#  - Αν έχουμε ένα δείγμα μάθησης $\{\boldsymbol{x_i},d_i \}$ όπου $d_i \in \{-1,+1 \}$ και $i = 1,2,\dots,N$, τότε ο περιορισμός που πρέπει να ισχυεί για τα περιθώρια είναι:
#  $d_{i}\left(\mathbf{w}^{\mathrm{T}} \mathbf{x}_{i}+b\right) \geq 1, i=1,2, \ldots, N$
#  - Στα support vector machines, η ευθεία που μεγιστοποιεί το περιθώριο είναι αυτή που επιλέγεται ως το βέλτιστο μοντέλο.

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
    yfit = m * xfit + b
    plt.plot(xfit, yfit, '-k')
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',
                     color='#AAAAAA', alpha=0.4)

plt.xlim(-1, 3.5);

# %% [markdown]
# ### Εκπαίδευση του Μοντέλου
#
# Χρησιμοποιώντας το πακέτο Scikit-Learn θα εκπαιδεύσουμε τον αλγόριθμο SVM πάνω στα δεδομένα του προηγούμενου προβλήματος, χρησιμοποιώντας γραμμικό πυρήνα.

# %%
model = SVC(kernel='linear', C=1E10)
model.fit(X, y)
# Out:
# SVC(C=10000000000.0, kernel='linear')

# %% [markdown]
# Με την παρακάτω μέθοδο θα εμφανιστεί στο σχήμα που ακολουθεί η βέλτιστη γραμμή διαχωρισμού των δύο κατηγοριών, καθώς και τα περιθώριά της. Τα training examples που ακουμπούν πάνω στα όρια ονομάζονται Support Vectors.

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    # plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model);

# %% [markdown]
# Στο ακόλουθο σχήμα, η διαδικασία επαναλαμβάνεται για δύο datasets που περιλαμβάνουν 60 και 120 training examples αντίστοιχα.
# <ul>
# <li><b>Ερώτηση 5:</b> Τι παρατηρείτε σχετικά με τη βέλτιστη γραμμή που διαχωρίζει τις δύο κατηγορίες και τα περιθώριά της;</li>
# <li><b>Ερώτηση 6:</b> Τι αρκεί να κάνει ο αλγόριθμος για να ταξινομήσει νέα δεδομένα που θα λάβει στην είσοδό του;</li>
# </ul>
#  <hr style="border:1px solid black"> </hr>
#
# - Παρατηρούμε ότι μόνο μερικά σημεία των δεδομένων ακουμπούν το περιθώριο, αυτά ουσιαστικά είναι τα support vectors. Επίσης, τα περιθώρια καθορίζονται μόνο από αυτά τα σημεία και όχι από τα υπόλοιπα σημεία των δεδομένων. Η γραμμή αυτή είναι η βέλτιστη.
# - Ο αλγόριθμος όταν λάβει νέα δεδομένα, αρκεί να κοιτάξει το πρόσημο $\mathbf{w}^{\mathrm{T}} \mathbf{x}_{i}+b$ και να τα ταξινομήσει κατάλληλα. Αν είναι θετικό κατατάσσεται στο $\boldsymbol{d_i} = +1$ αλλιώς αν είναι αρνητικό στο $\boldsymbol{d_i} = -1$.

# %%
def plot_svm(N=10, ax=None):
    X, y = make_blobs(n_samples=200, centers=2,
                      random_state=0, cluster_std=0.60)
    X = X[:N]
    y = y[:N]
    model = SVC(kernel='linear', C=1E10)
    model.fit(X, y)
    
    ax = ax or plt.gca()
    ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
    ax.set_xlim(-1, 4)
    ax.set_ylim(-1, 6)
    plot_svc_decision_function(model, ax)

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)
for axi, N in zip(ax, [60, 120]):
    plot_svm(N, axi)
    axi.set_title('N = {0}'.format(N))

# %% [markdown]
# ### Μη Γραμμικά Διαχωρίσιμες Κατηγορίες: Kernel SVM
#
# Στην περίπτωση που οι κατηγορίες του προβλήματος δεν είναι γραμμικά διαχωρίσιμες, ο αλγόριθμος SVM χρησιμοποιεί μη γραμμικούς πυρήνες (kernels) για να προβάλει τα δεδομένα εκπαίδευσης σε μεγαλύτερη διάσταση όπου μπορεί να τα καταστήσει γραμμικά διαχωρίσιμα. Μία τέτοια περίπτωση δεδομένων εκπαίδευσης παρουσιάζεται στο επόμενο σχήμα.

# %%
X, y = make_circles(100, factor=.1, noise=.1)

clf = SVC(kernel='linear').fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);

# %% [markdown]
# Είναι φανερό ότι τα δεδομένα εκπαίδευσης δεν μπορούν να διαχωριστούν γραμμικά. Στο επόμενο σχήμα φαίνεται η προβολή τους στις τρεις διαστάσεις με τη χρήση ενός μη γραμμικού πυρήνα.
# <ul>
# <li><b>Ερώτηση 7:</b> Τι είδους πυρήνας χρησιμοποιήθηκε;</li>
# <li><b>Ερώτηση 8:</b> Δώστε ένα παράδειγμα γραμμικού ορίου που θα μπορούσε να διαχωρίσει τις δύο κατηγορίες.</li>
# </ul>
#  <hr style="border:1px solid black"> </hr>
#
# - Χρησιμοποιήθηκε Gaussian Radial Basis Function ως kernel και συγκεκριμένα κεντραρισμένος στο μηδέν.
# $$ r(x) = e^{-x^2}$$
# - Ένα παράδειγμα γραμμικού ορίου που μπορεί να διαχωρίσει τις δύο κατηγορίες είναι για παράδειγμα το r=0.6 όπως φαίνεται στο παρακάτω διάγραμμα όπου έχει προστεθεί το r=0.6 plane.

# %%
r = np.exp(-(X ** 2).sum(1))
k = np.linspace(-1,1,30)
l = np.linspace(-1,1,30)
xx,yy = np.meshgrid(k,l)
z = 0.6

# %%
ax = plt.subplot(projection='3d')
ax.scatter(X[:, 0], X[:, 1], r, c=y, cmap='autumn')
ax.scatter(xx, yy,z,alpha=0.1, c='blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('r')
plt.show()

# %% [markdown]
# Η εύρεση του πυρήνα που μπορεί να διαχωρίσει με τον καλύτερο τρόπο τα δεδομένα απαιτεί, συνήθως, πολλούς υπολογισμούς.
# <ul>
# <li><b>Ερώτηση 9:</b> Ποια μέθοδος μπορεί να βοηθήσει σε αυτό και πώς; (hint: <a href="https://en.wikipedia.org/wiki/Kernel_trick">Kernel Trick</a>)</li>
# </ul>
#
# Παρακάτω γίνεται η εκπαίδευση του αλγορίθμου SVM με μη γραμμικό πυρήνα.
#
#  <hr style="border:1px solid black"> </hr>
# - Η εύρεση του βέλτιστου πυρήνα για τα δεδομένα μας, απαιτεί την προβολή $N$ σημείων σε $N$ διαστάσεις, το οποίο είναι υπολογιστικά ακριβό για μεγάλα $N$, συγκεκριμένα έχει πολυπλοκότητα $\mathcal{O}(N^2)$. Με το Kernel Trick, δεν χρειάζεται να υπολογίσουμε αναλυτικά τις συντεταγμένες των σημείων μας στο χώρο που βρίσκονται, αλλά αρκεί να τις βάλουμε ως input στην kernel function, να πάρουμε τις εικόνες τους και να υπολογίσουμε το εσωτερικό γινόμενο αυτών. Αυτό έχει πολυπλοκότητα $\mathcal{O}(N)$. Αυτό θεμελιώνεται και μαθηματικά από το θεώρημα Mercer*.
#
#  <hr style="border:1px solid black"> </hr>
#
# **Mercer's theorem states that a symmetric, and positive-definite matrix can be represented as a sum of a convergent sequence of product functions*

# %%
clf = SVC(kernel='rbf', C=1E6)
clf.fit(X, y)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf)
plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');
