# %% [markdown]
# ## Νικόλαος Μανιάτης
# ## Α.Μ.: 03400097
# ## email: nikolaosmaniatis@mail.ntua.gr

# %% [markdown]
# <h1><b>Ο αλγόριθμος Πολυωνυμικής Παλινδρόμησης (Polynomial Regression)</b></h1>
#
# <p align="justify">Στην άσκηση αυτή θα μελετήσετε τον αλγόριθμο <b><i>πολυωνυμικής παλινδρόμησης</i></b> (<b><i>polynomial regression</i></b>). Για την εκπαίδευση του μοντέλου θα χρησιμοποιήσετε τα δεδομένα του αρχείου <b><i><a href="https://github.com/nkostopoulos/StochasticsLabPublic/blob/master/lab1/data2.csv">data2.csv</a></b></i>. Η εφαρμογή αφορά την εκτίμηση των τιμών της πίεσης (pressure) ενός συστήματος δεδομένης της θερμοκρασίας (temperature).</p>
#
# <p align="justify">Στο Notebook αυτό περιλαμβάνονται εντολές για (α) τη φόρτωση των δεδομένων εκπαίδευσης που περιέχονται στο αρχείο <b><i>data2.csv</b></i>, (β) την εκπαίδευση ενός μοντέλου <b><i>linear regression</i></b> και την προσαρμογή του πάνω στα δεδομένα εκπαίδευσης, (γ) την εκπαίδευση ενός μοντέλου <b><i>polynomial regression</i></b> βαθμού <b><i>degree</i></b> και την προσαρμογή του πάνω στα δεδομένα εκπαίδευσης και (δ) την οπτικοποίηση των δεδομένων εκπαίδευσης, καθώς και των γραμμών απόφασης για τα δύο μοντέλα παλινδρόμησης. Για την εκπαίδευση των δύο μοντέλων παλινδρόμησης χρησιμοποιείται η βιβλιοθήκη <b><i>Scikit-Learn</b></i> της <b><i>Python</i></b>. Περισσότερες πληροφορίες για τον αλγόριθμο <b><i>polynomial regression</i></b> και τον κώδικα της άσκησης μπορούν να βρεθούν <a href="https://www.geeksforgeeks.org/python-implementation-of-polynomial-regression/">εδώ</a>.</p>
#
# <p align="justify">Στην άσκηση αυτή, καλείστε να παρατηρήσετε τη μορφή και τις αλλαγές της γραμμής παλινδρόμησης για διαφορετικές τιμές της παραμέτρου <b><i>degree</b></i> βάσει των δεδομένων εκπαίδευσης που παρέχονται.</p>
#
# <p align="justify">Αρχικά, θα εγκαταστήσετε και θα φορτώσετε τις απαραίτητες βιβλιοθήκες.</p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Στη συνέχεια, θα φορτώσετε τα δεδομένα εκπαίδευσης που παρέχονται από το αρχείο
#  <b><i>data2.csv</b></i>.

# %%
datas = pd.read_csv('https://raw.githubusercontent.com/nkostopoulos/StochasticsLabPublic/master/lab1/data2.csv')
print(datas)
# Out:
#     sno  Temperature  Pressure
# 0     1            0    0.0002
# 1     2            5    0.0010
# 2     3           10    0.0017
# 3     4           15    0.0040
# 4     5           20    0.0200
# 5     6           25    0.0400
# 6     7           30    0.0100
# 7     8           35    0.0340
# 8     9           40    0.0500
# 9    10           45    0.0600
# 10   11           50    0.0700
# 11   12           55    0.0800
# 12   13           60    0.0900
# 13   14           65    0.1000
# 14   15           70    0.1100

# %% [markdown]
# Τώρα, θα δημιουργήσετε τις μεταβλητές εισόδου και εξόδου για τους αλγορίθμους μηχανικής μάθησης από τα δεδομένα εκπαίδευσης που παρέχονται.

# %%
X = datas.iloc[:, 1:2].values
y = datas.iloc[:, 2].values

print("Input")

print(X)

print("Labels")

print(y)
# Out:
# Input
# [[ 0]
#  [ 5]
#  [10]
#  [15]
#  [20]
#  [25]
#  [30]
#  [35]
#  [40]
#  [45]
#  [50]
#  [55]
#  [60]
#  [65]
#  [70]]
# Labels
# [0.0002 0.001  0.0017 0.004  0.02   0.04   0.01   0.034  0.05   0.06
#  0.07   0.08   0.09   0.1    0.11  ]

# %% [markdown]
# Στη συνέχεια, θα εκπαιδεύσετε το μοντέλο <b><i>linear regression</i></b>, χρησιμοποιώντας τα παραπάνω δεδομένα εκπαίδευσης.

# %%
lin = LinearRegression()
lin.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# <h3><b><i>Ερώτημα 1</b></i></h3>
#
# <p align="justify">Να εκτελέσετε τα παρακάτω τμήματα κώδικα για τις τιμές της παραμέτρου <b><i>degree</b></i> {<i>2, 3, 4, 5, 8, 10, 12, 15</i>} και να καταγράψετε τα διαγράμματα που παρέχονται ως έξοδοι. Τι αλλαγές παρατηρείτε στη μορφή της γραμμής παλινδρόμησης για το μοντέλο <b><i>polynomial regression</i></b>, καθώς αυξάνεται η τιμή της παραμέτρου <b><i>degree</i></b>; Τι παρατηρείτε για τον απαιτούμενο χρόνο εκπαίδευσης του μοντέλου <b><i>polynomial regression</i></b>, καθώς αυξάνεται η τιμή της παραμέτρου <b><i>degree</i></b>;</p>
#
# <br>
#
# **<h4> <b><i>degree</b></i> = 2 </h4>**

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %%
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# <h4> <b><i>degree</b></i> = 4 </h4>

# %%
poly = PolynomialFeatures(degree=4)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# <h4> <b><i>degree</b></i> = 5 </h4>

# %%
poly = PolynomialFeatures(degree=5)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# <h4> <b><i>degree</b></i> = 8 </h4>

# %%
poly = PolynomialFeatures(degree=8)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# <h4> <b><i>degree</b></i> = 10 </h4>

# %%
poly = PolynomialFeatures(degree=10)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# <h4> <b><i>degree</b></i> = 12 </h4>

# %%
poly = PolynomialFeatures(degree=12)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# <h4> <b><i>degree</b></i> = 15 </h4>

# %%
poly = PolynomialFeatures(degree=15)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ### Σχολιασμός

# %% [markdown]
# Παρατηρούμε ότι καθώς αυξάνει ο βαθμός του πολυωνύμου, το μοντέλο αρχίζει και μαθαίνει καλύτερα τα δεδομένα, και προσαρμόζεται καλύτερα πάνω σε αυτά μαθαίνοντας
# και τις μικρότερες λεπτομέρειες που τα διέπουν. Αυτό όμως δεν είναι απαραίτητα καλό καθώς πολύ μεγάλος βαθμός πολυωνύμου έχει τέλεια προσαρμογή στα δεδομένα εκπαίδευσης
# όμως κινδυνεύει να κάνει Overfit, δηλαδή σε ένα test set θα είχε κακή απόδοση. Επίσης, όσο αυξάνει ο βαθμός του πολυωνύμου, τόσο περισσότερο επηρεάζεται το μοντέλο από outliers και σημεία επιρροής.

# %% [markdown]
# ## Χρόνοι εκτέλεσης

# %% [markdown]
# Παρακάτω, σχεδίασα ένα barplot με τους χρόνους εκπαίδευσης του polynomial regression αλγορίθμου σχετικά με τον βαθμό του πολυωνύμου.

# %%
import time

# %%
degrees = [2,4,5,8,10,12,13,14,15,16]
times = []
for i in degrees:
    poly = PolynomialFeatures(degree=i)
    X_poly = poly.fit_transform(X)
    tic = time.perf_counter()
    poly.fit(X_poly, y)
    toc = time.perf_counter()
    time_passed = toc-tic
    times.append(time_passed)

# %%
times
# Out:
# [9.890000001178123e-05,
#  5.7699999160831794e-05,
#  7.980000009411015e-05,
#  0.0021720999993704027,
#  0.03729159999966214,
#  0.4165627000002132,
#  1.6948596999991423,
#  6.566221900000528,
#  25.9282871000014,
#  104.58777849999933]

# %%
plt.bar(degrees,times)
plt.autoscale()
plt.xlabel('Degree of Polynomial')
plt.ylabel('Time of training in seconds')
# Out:
# Text(0, 0.5, 'Time of training in seconds')

# %% [markdown]
# Παρατηρούμε, ότι ο χρόνος εκτέλεσης για τους βαθμούς $degree < 10$ είναι αμελητέος, όμως αυξάνει καθώς αυξάνει ο βαθμός του πολυωνύμου, διότι αυτό σημαίνει ότι υπάρχουν περισσότερες παράμετροι να προσδιοριστούν. Σημαντικός αρχίζει και γίνεται ο χρόνος από $degree = 12,13$ και πάνω.

# %% [markdown]
# <h3><b><i>Ερώτημα 2</b></i></h3>
#
# Σας παρέχεται, επίσης, το αρχείο <b><i>data2b.csv</i></b>, το οποίο είναι το αρχείο <b><i>data2.csv</i></b> με μία παραπάνω εγγραφή, την <b><i>(6, 55, 0.1)</i></b>. Να εκτελέσετε το παρακάτω πρόγραμμα για την τιμή της παραμέτρου <b><i>degree = 15</i></b>. Πόσο μεγάλη είναι η αλλαγή που παρατηρείτε στη μορφή της γραμμής παλινδρόμησης σε σχέση με την αντίστοιχη περίπτωση του ερωτήματος 1; Τι συμπέρασμα μπορείτε να βγάλετε για τον αλγόριθμο <b><i>polynomial regression</i></b>;

# %%
datas = pd.read_csv('https://raw.githubusercontent.com/nkostopoulos/StochasticsLabPublic/master/lab1/data2b.csv')
print(datas)

X = datas.iloc[:, 1:2].values
y = datas.iloc[:, 2].values

lin = LinearRegression()
lin.fit(X, y)

poly = PolynomialFeatures(degree=15)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

plt.scatter(X, y, color = 'blue', label = 'Training Examples')

plt.plot(X, lin.predict(X), color = 'red', label = 'Linear Regression Line')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'green', label = 'Polynomial Regression Line')
plt.legend()
plt.show()
# Out:
#     sno  Temperature  Pressure
# 0     1            0    0.0002
# 1     2            5    0.0010
# 2     3           10    0.0017
# 3     4           15    0.0040
# 4     5           20    0.0200
# 5     6           25    0.0400
# 6     7           30    0.0100
# 7     8           35    0.0340
# 8     9           38    0.3000
# 9    10           40    0.0500
# 10   11           45    0.0600
# 11   12           50    0.0700
# 12   13           55    0.0800
# 13   14           60    0.0900
# 14   15           65    0.1000
# 15   16           70    0.1100

# %% [markdown]
# ## Σχολιασμός

# %% [markdown]
# Το σημείο που προστέθηκε στα δεδομένα μας, απέχει πολύ από τα υπόλοιπα, οπότε μπορεί να θεωρηθεί ως outlier. Αυτό που συμπεραίνουμε για το μοντέλο μας το οποίο έχει βαθμό 15, είναι ότι έχει κάνει overfit, επειδή ο βαθμός του πολυωνύμου είναι πολύ μεγάλος επομένως έχει μεγάλη ευαισθησία σε outliers, και γι'αυτό χάνει το γενικότερο trend των υπόλοιπων δεδομένων καθώς το σημείο που προστέθηκε του προκαλεί ένα μεγάλο bump. Κάτι τέτοιο δεν ισχύει για το ερώτημα 1 καθώς τα δεδομένα είναι σχετικά κοντά μεταξύ τους, και δεν υπάρχει κάποιο σημείο το οποίο να ασκεί τόσο μεγάλη επιρροή όπως εδώ.
