# %% [markdown]
# ### Νικόλαος Μανιάτης
# #### Α.Μ.: 03400097
# (απαντήσεις στο τέλος)

# %% [markdown]
# <h1><b><i>Ο αλγόριθμος Προσομοιωμένης Ανόπτησης</i> (<i>Simulated Annealing</i>)</b></h1>
#
# Στην άσκηση αυτή θα μελετήσετε τον αλγόριθμο της <i>Προσομοιωμένης Ανόπτησης</i> (<i>Simulated Annealing</i>), περισσότερες πληροφορίες για τον οποίο μπορείτε να βρείτε <a href="https://en.wikipedia.org/wiki/Simulated_annealing">εδώ</a>.Θα χρησιμοποιήσετε τα <b>δύο έτοιμα</b> προγράμματα που δίνονται στη συνέχεια. Τα προγράμματα αυτά επιλύουν το πρόβλημα του <i>Περιπλανώμενου Πωλητή</i> (<i>Travelling Salesman Problem</i>, <i>TSP</i>), περισσότερες πληροφορίες για το οποίο μπορείτε να βρείτε <a href="https://en.wikipedia.org/wiki/Travelling_salesman_problem">εδώ</a>. Το πρώτο πρόγραμμα επιλύει το πρόβλημα <i>TSP</i> χρησιμοποιώντας τον αλγόριθμο <i>Simulated Annealing</i> και το δεύτερο επιλύει το ίδιο πρόβλημα, χρησιμοποιώντας τον αλγόριθμο <a href="https://en.wikipedia.org/wiki/Hill_climbing"><i>Hill Climbing</i></a>. Η επίλυση του προβλήματος γίνεται για <b>150 πόλεις</b>.
#
# <b>Σημείωση:</b> Βεβαιωθείτε ότι το <b><i>Runtime Environment</i></b> είναι για <b><i>Python 2</i></b>.

# %% [markdown]
# <h2><b><i>Simulated Annealing</i></b></h2>

# %%
#!/usr/bin/env python

""" Traveling salesman problem solved using Simulated Annealing.
http://www.physics.rutgers.edu/~haule/681/src_MC/python_codes/salesman.py
"""
from scipy import *
from pylab import *

def Distance(R1, R2):
    return sqrt((R1[0]-R2[0])**2+(R1[1]-R2[1])**2)

def TotalDistance(city, R):
    dist=0
    for i in range(len(city)-1):
        dist += Distance(R[city[i]],R[city[i+1]])
    dist += Distance(R[city[-1]],R[city[0]])
    return dist
    
def reverse(city, n):
    nct = len(city)
    nn = (1+ ((n[1]-n[0]) % nct))/2 # half the lenght of the segment to be reversed
    # the segment is reversed in the following way n[0]<->n[1], n[0]+1<->n[1]-1, n[0]+2<->n[1]-2,...
    # Start at the ends of the segment and swap pairs of cities, moving towards the center.
    for j in range(nn):
        k = (n[0]+j) % nct
        l = (n[1]-j) % nct
        (city[k],city[l]) = (city[l],city[k])  # swap
    
def transpt(city, n):
    nct = len(city)
    
    newcity=[]
    # Segment in the range n[0]...n[1]
    for j in range( (n[1]-n[0])%nct + 1):
        newcity.append(city[ (j+n[0])%nct ])
    # is followed by segment n[5]...n[2]
    for j in range( (n[2]-n[5])%nct + 1):
        newcity.append(city[ (j+n[5])%nct ])
    # is followed by segment n[3]...n[4]
    for j in range( (n[4]-n[3])%nct + 1):
        newcity.append(city[ (j+n[3])%nct ])
    return newcity

def Plot(city, R, dist):
    # Plot
    Pt = [R[city[i]] for i in range(len(city))]
    Pt += [R[city[0]]]
    Pt = array(Pt)
    title('Total distance='+str(dist))
    plot(Pt[:,0], Pt[:,1], '-o')
    show()

if __name__=='__main__':

    ncity = 150        # Number of cities to visit
    maxTsteps = 100    # Temperature is lowered not more than maxTsteps
    Tstart = 0.2       # Starting temperature - has to be high enough
    fCool = 0.9        # Factor to multiply temperature at each cooling step
    maxSteps = 100*ncity     # Number of steps at constant temperature
    maxAccepted = 10*ncity   # Number of accepted steps at constant temperature

    Preverse = 0.5      # How often to choose reverse/transpose trial move

    # Choosing city coordinates
    R=[]  # coordinates of cities are choosen randomly
    for i in range(ncity):
        R.append( [rand(),rand()] )
    R = array(R)

    # The index table -- the order the cities are visited.
    city = range(ncity)
    # Distance of the travel at the beginning
    dist = TotalDistance(city, R)

    # Stores points of a move
    n = zeros(6, dtype=int)
    nct = len(R) # number of cities
    
    T = Tstart # temperature
    number = 0 
    Plot(city, R, dist)
    for t in range(maxTsteps):  # Over temperature

        accepted = 0
        for i in range(maxSteps): # At each temperature, many Monte Carlo steps
            
            while True: # Will find two random cities sufficiently close by
                # Two cities n[0] and n[1] are choosen at random
                n[0] = int((nct)*rand())     # select one city
                n[1] = int((nct-1)*rand())   # select another city, but not the same
                if (n[1] >= n[0]): n[1] += 1   #
                if (n[1] < n[0]): (n[0],n[1]) = (n[1],n[0]) # swap, because it must be: n[0]<n[1]
                nn = (n[0]+nct -n[1]-1) % nct  # number of cities not on the segment n[0]..n[1]
                if nn>=3: break
        
            # We want to have one index before and one after the two cities
            # The order hence is [n2,n0,n1,n3]
            n[2] = (n[0]-1) % nct  # index before n0  -- see figure in the lecture notes
            n[3] = (n[1]+1) % nct  # index after n2   -- see figure in the lecture notes
            
            if Preverse > rand(): 
                # Here we reverse a segment
                # What would be the cost to reverse the path between city[n[0]]-city[n[1]]?
                de = Distance(R[city[n[2]]],R[city[n[1]]]) + Distance(R[city[n[3]]],R[city[n[0]]]) - Distance(R[city[n[2]]],R[city[n[0]]]) - Distance(R[city[n[3]]],R[city[n[1]]])
                
                if de<0 or exp(-de/T)>rand(): # Metropolis
                    accepted += 1
                    dist += de
                    reverse(city, n)
            else:
                # Here we transpose a segment
                nc = (n[1]+1+ int(rand()*(nn-1)))%nct  # Another point outside n[0],n[1] segment. See picture in lecture nodes!
                n[4] = nc
                n[5] = (nc+1) % nct
        
                # Cost to transpose a segment
                de = -Distance(R[city[n[1]]],R[city[n[3]]]) - Distance(R[city[n[0]]],R[city[n[2]]]) - Distance(R[city[n[4]]],R[city[n[5]]])
                de += Distance(R[city[n[0]]],R[city[n[4]]]) + Distance(R[city[n[1]]],R[city[n[5]]]) + Distance(R[city[n[2]]],R[city[n[3]]])
                
                if de<0 or exp(-de/T)>rand(): # Metropolis
                    accepted += 1
                    dist += de
                    city = transpt(city, n)
                    
            if accepted > maxAccepted: break

        # Plot
        
        Plot(city, R, dist)
        number +=1 
            
        print "T=%10.5f , distance= %10.5f , accepted steps= %d, number of plots = %d" %(T, dist, accepted, number)
        T *= fCool             # The system is cooled down
        if accepted == 0: break  # If the path does not want to change any more, we can stop
# Out:
# T=   0.20000 , distance=   44.24756 , accepted steps= 1501, number of plots = 1
# T=   0.18000 , distance=   40.04666 , accepted steps= 1501, number of plots = 2
# T=   0.16200 , distance=   38.67838 , accepted steps= 1501, number of plots = 3
# T=   0.14580 , distance=   35.07317 , accepted steps= 1501, number of plots = 4
# T=   0.13122 , distance=   32.67052 , accepted steps= 1501, number of plots = 5
# T=   0.11810 , distance=   29.17784 , accepted steps= 1501, number of plots = 6
# T=   0.10629 , distance=   25.49952 , accepted steps= 1341, number of plots = 7
# T=   0.09566 , distance=   25.41417 , accepted steps= 1082, number of plots = 8
# T=   0.08609 , distance=   24.93197 , accepted steps= 917, number of plots = 9
# T=   0.07748 , distance=   21.03715 , accepted steps= 775, number of plots = 10
# T=   0.06974 , distance=   22.14810 , accepted steps= 628, number of plots = 11
# T=   0.06276 , distance=   18.26084 , accepted steps= 497, number of plots = 12
# T=   0.05649 , distance=   17.12411 , accepted steps= 410, number of plots = 13
# T=   0.05084 , distance=   16.80210 , accepted steps= 380, number of plots = 14
# T=   0.04575 , distance=   14.93053 , accepted steps= 282, number of plots = 15
# T=   0.04118 , distance=   15.05005 , accepted steps= 254, number of plots = 16
# T=   0.03706 , distance=   13.68386 , accepted steps= 210, number of plots = 17
# T=   0.03335 , distance=   13.30895 , accepted steps= 186, number of plots = 18
# T=   0.03002 , distance=   12.62955 , accepted steps= 153, number of plots = 19
# T=   0.02702 , distance=   12.15114 , accepted steps= 116, number of plots = 20
# T=   0.02432 , distance=   11.53889 , accepted steps= 103, number of plots = 21
# T=   0.02188 , distance=   11.02719 , accepted steps= 66, number of plots = 22
# T=   0.01970 , distance=   10.63995 , accepted steps= 68, number of plots = 23
# T=   0.01773 , distance=   10.56863 , accepted steps= 57, number of plots = 24
# T=   0.01595 , distance=   10.23177 , accepted steps= 34, number of plots = 25
# T=   0.01436 , distance=   10.12861 , accepted steps= 48, number of plots = 26
# T=   0.01292 , distance=   10.20988 , accepted steps= 44, number of plots = 27
# T=   0.01163 , distance=    9.85007 , accepted steps= 28, number of plots = 28
# T=   0.01047 , distance=    9.83844 , accepted steps= 15, number of plots = 29
# T=   0.00942 , distance=    9.82749 , accepted steps= 24, number of plots = 30
# T=   0.00848 , distance=    9.78675 , accepted steps= 18, number of plots = 31
# T=   0.00763 , distance=    9.76731 , accepted steps= 17, number of plots = 32
# T=   0.00687 , distance=    9.70254 , accepted steps= 13, number of plots = 33
# T=   0.00618 , distance=    9.70491 , accepted steps= 10, number of plots = 34
# T=   0.00556 , distance=    9.60144 , accepted steps= 17, number of plots = 35
# T=   0.00501 , distance=    9.57658 , accepted steps= 12, number of plots = 36
# T=   0.00451 , distance=    9.58441 , accepted steps= 9, number of plots = 37
# T=   0.00406 , distance=    9.57062 , accepted steps= 9, number of plots = 38
# T=   0.00365 , distance=    9.56445 , accepted steps= 7, number of plots = 39
# T=   0.00328 , distance=    9.58486 , accepted steps= 5, number of plots = 40
# T=   0.00296 , distance=    9.58510 , accepted steps= 6, number of plots = 41
# T=   0.00266 , distance=    9.56843 , accepted steps= 8, number of plots = 42
# T=   0.00239 , distance=    9.55967 , accepted steps= 4, number of plots = 43
# T=   0.00216 , distance=    9.55994 , accepted steps= 1, number of plots = 44
# T=   0.00194 , distance=    9.56044 , accepted steps= 5, number of plots = 45
# T=   0.00175 , distance=    9.55695 , accepted steps= 4, number of plots = 46
# T=   0.00157 , distance=    9.55705 , accepted steps= 2, number of plots = 47
# T=   0.00141 , distance=    9.56298 , accepted steps= 3, number of plots = 48
# T=   0.00127 , distance=    9.56309 , accepted steps= 3, number of plots = 49
# T=   0.00115 , distance=    9.55734 , accepted steps= 6, number of plots = 50
# T=   0.00103 , distance=    9.49530 , accepted steps= 7, number of plots = 51
# T=   0.00093 , distance=    9.49493 , accepted steps= 2, number of plots = 52
# T=   0.00083 , distance=    9.49493 , accepted steps= 2, number of plots = 53
# T=   0.00075 , distance=    9.49514 , accepted steps= 3, number of plots = 54
# T=   0.00068 , distance=    9.49564 , accepted steps= 5, number of plots = 55
# T=   0.00061 , distance=    9.49493 , accepted steps= 4, number of plots = 56
# T=   0.00055 , distance=    9.49553 , accepted steps= 2, number of plots = 57
# T=   0.00049 , distance=    9.49519 , accepted steps= 3, number of plots = 58
# T=   0.00044 , distance=    9.49514 , accepted steps= 2, number of plots = 59
# T=   0.00040 , distance=    9.49493 , accepted steps= 3, number of plots = 60
# T=   0.00036 , distance=    9.49493 , accepted steps= 0, number of plots = 61

# %% [markdown]
# <h2><b><i>Hill Climbing</i></b></h2>

# %%
#!/usr/bin/env python

""" Traveling salesman problem solved using Simulated Annealing.
http://www.physics.rutgers.edu/~haule/681/src_MC/python_codes/salesman.py
"""
from scipy import *
from pylab import *

def Distance(R1, R2):
    return sqrt((R1[0]-R2[0])**2+(R1[1]-R2[1])**2)

def TotalDistance(city, R):
    dist=0
    for i in range(len(city)-1):
        dist += Distance(R[city[i]],R[city[i+1]])
    dist += Distance(R[city[-1]],R[city[0]])
    return dist
    
def reverse(city, n):
    nct = len(city)
    nn = (1+ ((n[1]-n[0]) % nct))/2 # half the lenght of the segment to be reversed
    # the segment is reversed in the following way n[0]<->n[1], n[0]+1<->n[1]-1, n[0]+2<->n[1]-2,...
    # Start at the ends of the segment and swap pairs of cities, moving towards the center.
    for j in range(nn):
        k = (n[0]+j) % nct
        l = (n[1]-j) % nct
        (city[k],city[l]) = (city[l],city[k])  # swap
    
def transpt(city, n):
    nct = len(city)
    
    newcity=[]
    # Segment in the range n[0]...n[1]
    for j in range( (n[1]-n[0])%nct + 1):
        newcity.append(city[ (j+n[0])%nct ])
    # is followed by segment n[5]...n[2]
    for j in range( (n[2]-n[5])%nct + 1):
        newcity.append(city[ (j+n[5])%nct ])
    # is followed by segment n[3]...n[4]
    for j in range( (n[4]-n[3])%nct + 1):
        newcity.append(city[ (j+n[3])%nct ])
    return newcity

def Plot(city, R, dist):
    # Plot
    Pt = [R[city[i]] for i in range(len(city))]
    Pt += [R[city[0]]]
    Pt = array(Pt)
    title('Total distance='+str(dist))
    plot(Pt[:,0], Pt[:,1], '-o')
    show()

if __name__=='__main__':

    ncity = 150       # Number of cities to visit
    maxTsteps = 100    # Temperature is lowered not more than maxTsteps
    Tstart = 0.2       # Starting temperature - has to be high enough
    fCool = 0.9        # Factor to multiply temperature at each cooling step
    maxSteps = 100*ncity     # Number of steps at constant temperature
    maxAccepted = 10*ncity   # Number of accepted steps at constant temperature

    Preverse = 0.5      # How often to choose reverse/transpose trial move

    # Choosing city coordinates
    R=[]  # coordinates of cities are choosen randomly
    for i in range(ncity):
        R.append( [rand(),rand()] )
    R = array(R)

    # The index table -- the order the cities are visited.
    city = range(ncity)
    # Distance of the travel at the beginning
    dist = TotalDistance(city, R)

    # Stores points of a move
    n = zeros(6, dtype=int)
    nct = len(R) # number of cities
    
    T = Tstart # temperature
    number = 0 
    Plot(city, R, dist)
    
    for t in range(maxTsteps):  # Over temperature

        accepted = 0
        for i in range(maxSteps): # At each temperature, many Monte Carlo steps
            
            while True: # Will find two random cities sufficiently close by
                # Two cities n[0] and n[1] are choosen at random
                n[0] = int((nct)*rand())     # select one city
                n[1] = int((nct-1)*rand())   # select another city, but not the same
                if (n[1] >= n[0]): n[1] += 1   #
                if (n[1] < n[0]): (n[0],n[1]) = (n[1],n[0]) # swap, because it must be: n[0]<n[1]
                nn = (n[0]+nct -n[1]-1) % nct  # number of cities not on the segment n[0]..n[1]
                if nn>=3: break
        
            # We want to have one index before and one after the two cities
            # The order hence is [n2,n0,n1,n3]
            n[2] = (n[0]-1) % nct  # index before n0  -- see figure in the lecture notes
            n[3] = (n[1]+1) % nct  # index after n2   -- see figure in the lecture notes
            
            if Preverse > rand(): 
                # Here we reverse a segment
                # What would be the cost to reverse the path between city[n[0]]-city[n[1]]?
                de = Distance(R[city[n[2]]],R[city[n[1]]]) + Distance(R[city[n[3]]],R[city[n[0]]]) - Distance(R[city[n[2]]],R[city[n[0]]]) - Distance(R[city[n[3]]],R[city[n[1]]])
                
                if de<0:
                    accepted += 1
                    dist += de
                    reverse(city, n)
            else:
                # Here we transpose a segment
                nc = (n[1]+1+ int(rand()*(nn-1)))%nct  # Another point outside n[0],n[1] segment. See picture in lecture nodes!
                n[4] = nc
                n[5] = (nc+1) % nct
        
                # Cost to transpose a segment
                de = -Distance(R[city[n[1]]],R[city[n[3]]]) - Distance(R[city[n[0]]],R[city[n[2]]]) - Distance(R[city[n[4]]],R[city[n[5]]])
                de += Distance(R[city[n[0]]],R[city[n[4]]]) + Distance(R[city[n[1]]],R[city[n[5]]]) + Distance(R[city[n[2]]],R[city[n[3]]])
                
                if de<0:
                    accepted += 1
                    dist += de
                    city = transpt(city, n)
                    
            if accepted > maxAccepted: break

        # Plot
        Plot(city, R, dist)
        number +=1
        print "T=%10.5f , distance= %10.5f , accepted steps= %d, number of plots = %d" %(T, dist, accepted,number)
        T *= fCool             # The system is cooled down
        if accepted == 0: break  # If the path does not want to change any more, we can stop

        
    Plot(city, R, dist)
# Out:
# T=   0.20000 , distance=   15.22314 , accepted steps= 417, number of plots = 1
# T=   0.18000 , distance=   12.65194 , accepted steps= 56, number of plots = 2
# T=   0.16200 , distance=   11.26058 , accepted steps= 29, number of plots = 3
# T=   0.14580 , distance=   10.98314 , accepted steps= 13, number of plots = 4
# T=   0.13122 , distance=   10.75523 , accepted steps= 6, number of plots = 5
# T=   0.11810 , distance=   10.64036 , accepted steps= 3, number of plots = 6
# T=   0.10629 , distance=   10.57628 , accepted steps= 2, number of plots = 7
# T=   0.09566 , distance=   10.47547 , accepted steps= 2, number of plots = 8
# T=   0.08609 , distance=   10.47547 , accepted steps= 0, number of plots = 9

# %% [markdown]
# <h3><b><i>Ερωτήσεις</i></b></h3>
#
# <lu>
# <li>Να διατυπώσετε το πρόβλημα <i>TSP</i>.</li>
# <br>
# <li>Να περιγράψετε, σύντομα, τη λειτουργία του αλγορίθμου <i>Hill Climbing</i> και να εξηγήσετε γιατί μπορεί να οδηγήσει σε κακές λύσεις.</li>
# <br>
# <li>Να περιγράψετε, σύντομα, τη λειτουργία του αλγορίθμου <i>Simulated Annealing</i> και γιατί είναι δυνατό να οδηγήσει σε καλύτερες λύσεις από τον αλγόριθμο <i>Hill Climbing</i>.</li>
# <br>
# <li>Να εκτελέσετε τα παραπάνω προγράμματα. Να καταγράψετε τις εξόδους τους. Δεν είναι απαραίτητο να κρατήσετε όλα τα διαγράμματα, αλλά μερικά από τα πιο αντιπροσωπευτικά.</li>
# <br>
# <li>Να σχολιάσετε τις διαφορές των δύο αλγορίθμων ως προς την τιμή της τελικής λύσης και το συνολικό αριθμό των βημάτων που απαιτούνται για να οδηγηθούμε σε αυτήν. Ποιος αλγόριθμος επιλέγει την καλύτερη λύση; Ποιος αλγόριθμος καθυστερεί πιο πολύ;</li>
# <br>
# <li>Μελετώντας τα διαγράμματα που επιστρέφουν ως έξοδο τα παραπάνω προγράμματα, να σχολιάσετε πόσο απότομες είναι οι μεταβολές ανάμεσα στις λύσεις που επιστρέφουν οι αλγόριθμοι σε κάθε βήμα μέχρι να φτάσουν στην τελική λύση. Σε ένα δεδομένο βήμα, επιλέγεται πάντα μια καλύτερη λύση ή κάποιος από τους δύο αλγορίθμους επιλέγει και χειρότερες λύσεις;</li>
# </lu>
#
# ----------------------------

# %% [markdown]
# > - Να διατυπώσετε το πρόβλημα TSP.
#
# Στο Travelling Salesman Problem, ψάχνουμε την βέλτιστη διαδρομή δεδομένης μιας λίστας με Ν πόλεις και τις αποστάσεις μεταξύ κάθε ζεύγους πόλεων (ανά δύο), η οποία διαδρομή περνάει από κάθε πόλυ μια φορά μόνο, και επιστρέφει στην πόλη απ'την οποία ξεκινήσαμε.

# %% [markdown]
# > - Να περιγράψετε, σύντομα, τη λειτουργία του αλγορίθμου Hill Climbing και να εξηγήσετε γιατί μπορεί να οδηγήσει σε κακές λύσεις.
#
# Ο αλγόριθμος hill climbing είναι ένας αλγόριθμος τοπικής αναζήτησης μεγίστων. Ουσιαστικά, κινείται κάθε φορά προς την κατεύθυνση αυξανόμενης τιμής έτσι ώστε να βρει το μέγιστο, ή την βέλτιστη λύση του προβλήματος. Σταματάει, όταν καμία γειτονική τιμή δεν είναι μεγαλύτερη από αυτή στην οποία βρίσκεται.
# Είναι προφανές ότι ένας τέτοιος αλγόριθμος, ψάχνοντας το τοπικό μέγιστο, μπορεί να παγιδευτεί σε ένα τέτοιο, και να αγνοήσει την ύπαρξη ενός ολικού μεγίστου. Επίσης, εξαρτάται έντονα από την αρχική του κατάσταση αφού εξερευνεί και βρίσκει το μέγιστο εντός της γειτονιάς γύρω από την αρχική κατάσταση.

# %% [markdown]
# > - Να περιγράψετε, σύντομα, τη λειτουργία του αλγορίθμου Simulated Annealing και γιατί είναι δυνατό να οδηγήσει σε καλύτερες λύσεις από τον αλγόριθμο Hill Climbing.
#
# Η μέθοδος simulated annealing αποσκοπεί στην εύρεση ενός global μεγίστου (ή ελαχίστου) μιας δεδομένης συνάρτησης. Είναι μια πιθανοτική μέθοδος, σε κάθε επανάληψη, μια γειτονική κατάσταση από την $s$ ευρενάται, έστω $s^*$, και ο αλγόριθμος με βάση μια πιθανότητα αποφασίζει αν θα μείνει στην $s$ ή θα μεταβεί στην $s^*$. Έτσι, με αυτόν τον τρόπο το σύστημα οδηγείται σε καταστάσεις χαμηλότερης «ενέργειας». Ο αλγόριθμος σταματάει όταν έχουμε μια κατάσταση η οποία είναι ικανοποιητική ή όταν έχουμε ξεπεράσει κάποιο κατώφλι. Ο αλγόριθμος hill climbing θα αποτύχει να βρει ένα ολικό optimum μιας non convex συνάρτησης καθώς κατά πάσα πιθανότητα θα παγιδευτεί σε ένα τοπικό ελάχιστο/μέγιστο. Αντιθέτως, ο αλγόριθμος simulated annealing θα οδηγήσει σε καλύτερες λύσεις, και αυτό συμβαίνει διότι σε κάποια βήματα επιτρέπει την μετάβαση σε «χειρότερες» καταστάσεις, έτσι ώστε να ξεφύγει από local optima, π.χ. η κίνηση προς τα πάνω προκειμένου να ξεφύγει από τοπικό ελάχιστο.

# %% [markdown]
# > -  Να εκτελέσετε τα παραπάνω προγράμματα. Να καταγράψετε τις εξόδους τους. Δεν είναι απαραίτητο να κρατήσετε όλα τα διαγράμματα, αλλά μερικά από τα πιο αντιπροσωπευτικά.
#
# Τα προγράμματα είναι τρεγμένα στα παραπάνω κελιά.

# %% [markdown]
# > - Να σχολιάσετε τις διαφορές των δύο αλγορίθμων ως προς την τιμή της τελικής λύσης και το συνολικό αριθμό των βημάτων που απαιτούνται για να οδηγηθούμε σε αυτήν. Ποιος αλγόριθμος επιλέγει την καλύτερη λύση; Ποιος αλγόριθμος καθυστερεί πιο πολύ;

# %% [markdown]
# Ο αλγόριθμος simulated annealing, φτάνει σε μια τελική τιμή απόστασης $D = 9.49$, ενώ ο αλγόριθμος Hill Climbing σε μια τελική τιμή $ D = 10.47$.
# Ο simulated annealing επιτυγχάνει αυτό το αποτέλεσμα σε περίπου 50 βήματα ενώ ο Hill Climbing σε περίπου 8. Αυτό είναι αναμενόμενο, καθώς ο hill climbing ως ακριβής αλγόριθμος κάνει πάντα τις "σωστές κινήσεις", χωρίς να συγκλίνει στο ολικό ελάχιστο καθώς εγκλωβίζεται σε τοπικά ελάχιστα, ενώ ο Simulated Annealing καθώς υπάρχει μια πιθανότητα να κάνει "λάθος κίνηση" χρειάζεται περισσότερες επαναλήψεις καθώς εξερευνεί το χώρο, για αυτό όμως και καταφέρνει και βρίσκει το ολικό ελάχιστο και δεν εγκλωβίζεται σε τοπικά ελάχιστα.

# %% [markdown]
# > - Μελετώντας τα διαγράμματα που επιστρέφουν ως έξοδο τα παραπάνω προγράμματα, να σχολιάσετε πόσο απότομες είναι οι μεταβολές ανάμεσα στις λύσεις που επιστρέφουν οι αλγόριθμοι σε κάθε βήμα μέχρι να φτάσουν στην τελική λύση. Σε ένα δεδομένο βήμα, επιλέγεται πάντα μια καλύτερη λύση ή κάποιος από τους δύο αλγορίθμους επιλέγει και χειρότερες λύσεις;
#
#
#
# Ο αλγόριθμος hill climbing είναι πιο απότομος καθώς μέσα σε μια μόνο κίνηση μειώνει κατά πολύ τη απόσταση η οποία είναι κοντά στο τελικό ελάχιστο επειδή κάθε φορά κάνει "σωστή κίνηση", ενώ ο αλγόριθμος simulated annealing καθώς όπως αναφέραμε ήδη έχει πιθανότητα να κάνει "λάθος κίνηση", φτάνει στο ελάχιστο σε περισσότερα και πιο ομαλά βήματα.
